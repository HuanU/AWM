# %%
#Authors: Eli Gumble, Peter Brommer, Harry Brown
#Initialisation
import matplotlib.pyplot as plt
import numpy as np
#from scipy.integrate import simps
from scipy import signal as sg
from scipy.interpolate import RectBivariateSpline as ReBiSpline 
from numpy import ma
#from matplotlib import colors, ticker, cm
#from random import choice
import scipy.ndimage.filters as filters
import scipy.ndimage.morphology as morphology
import timeit
import math
#from PIL import Image

import matplotlib.image as image2
import itertools
from scipy import ndimage
import multiprocessing
from multiprocessing import Pool
import multiprocessedfunctions as mpf
import multiprocessedfunctions2 as mpf2
import multiprocessedfunctions6 as mpf6
import multiprocessedfunctions10 as mpf10
import multiprocessedfunctions8 as mpf8
import multiprocessedfunctions3 as mpf3
import multiprocessedfunctions3_2 as mpf3_2
from globalparameters import * # parameters below have been relocated into globalparameters.py
#from scipy import stats
#import statistics
from datetime import datetime
import time
import copy


# %matplotlib inline

# %%
# Read grids from image
#im = Image.open("belgiumtest.bmp")
#Base = np.array(im)

#im = image2.imread("belgiumtestorig2x.bmp")
im = image2.imread("empty200x200grass.bmp")
#im = image2.imread("empty400x400grass.bmp")

#im = image2.imread("madeleine1200x2400.bmp")
#im = image2.imread("fieldwithcrops260x400.bmp")
Base = np.array(im)

# %%
#print(Base[0,0,1])
#Base = np.where(Base[:,:,0]==43, 0, Base)
#Base

#                        [[r, g, r2, g2]...]     description
landcoverlist = np.array([[22, 95, 0, 0],           # water
                          [209, 209, 150, 150],       # bare floor
                          [139, 139, 175, 175],     # artificial surface
                          [221, 5, 0, 0],           # building
                          [255, 255, 0, 200],            # herbaceous cover in rotation throughout year
                          [234, 255, 70, 200],       # herbaceous cover (grass)
                          [40, 202, 40, 200],        # tall hardwood > 3m
                          [185, 233, 30, 200],       # short hardwood < 3m
                          [1, 47, 65, 200],          # tall softwood > 3m
                          #[0, 0, 0, 0],            # short softwood < 3m
                          [43, 80, 0, 0]])          # boundary
                                        
#len(landcoverlist)

for k in range (len(landcoverlist)):
    for i in range(len(Base)):             #vertical pixels
        for j in range(len(Base[0])):      #horizontal pixels
            if Base[i][j][0] == landcoverlist[k,0] and Base[i][j][1] == landcoverlist[k,1]:
                Base[i][j] = [landcoverlist[k,2],landcoverlist[k,3],0,255]

# %%
Base[:,:,2] = 0 #set all pixel B values to 0

Base[:,:,3] = 255 #set all of the 4th rgb element to 255 because things might break otherwise

# %%
# Define internal quantities and variables
scale = 1./2. #m per pixel
Nx = Base[:,0,0].size #N appears to be resolution
Ny = Base[0,:,0].size
xmin=-scale*0.5*(Nx-1)
xmax=scale*0.5*(Nx-1)
ymin=-scale*0.5*(Ny-1)
ymax=scale*0.5*(Ny-1)
x = np.linspace(xmin, xmax, Nx) # This is defining the axes and full space
y = np.linspace(ymin, ymax, Ny)
Y, X= np.meshgrid(y, x)
TrailPotential = np.zeros((Nx,Ny))
DestinationPotential=np.zeros((Nx,Ny))
Weight=np.zeros((Nx,Ny))  # Create gradient to sit on Nx, Ny
intens=np.zeros((Nx,Ny))
q_alpha=np.zeros((Nx,Ny))
expdist=np.zeros((2*Nx-1,2*Ny-1))
dest=np.zeros((2))
start=np.zeros((2))
grad=np.zeros((2,Nx,Ny))
vel=np.asarray([0.,0.])
pos=np.asarray([0.,0.])
stalledpos = [] # empty container for stalled positions of walkers
stalledposrounded = []

intens[:]=0.
isigma=0.2 # functions as 'smoothing intensity' of trail potentials, value < 0.5 leads to more smoothing, can cause more path merging and fewer straight lines
#t._track=25. # Track decay time - after 50 walkers ignore a trail, it decays by 1/e
wlkr_range = 10000
#print(route)
'''
#parameters
dt=0.1  # dt per time step, continuous markings every dt metres
dvel=1. # desired walker velocity in m/s
tau=5.
isigma=0.5 # trail potential
trailpotweight = 0.004 # weighting of trail potential over destination potential, started as 0.003, increasing this increases number of stalls
storedtrailpotweight = trailpotweight
conv_thresh=10.e-4
precision=1.**2 #distance to target.
eps=0.025 #random motion contribution, same for all
'''
# Out:
# '\n#parameters\ndt=0.1  # dt per time step, continuous markings every dt metres\ndvel=1. # desired walker velocity in m/s\ntau=5.\nisigma=0.5 # trail potential\ntrailpotweight = 0.004 # weighting of trail potential over destination potential, started as 0.003, increasing this increases number of stalls\nstoredtrailpotweight = trailpotweight\nconv_thresh=10.e-4\nprecision=1.**2 #distance to target.\neps=0.025 #random motion contribution, same for all\n'

# %%
##Set up map
#Create blank arrays for map 
z = np.zeros((Nx,Ny))
g_max=np.zeros((Nx,Ny))
g_nat=np.zeros((Nx,Ny))

g_nat=np.maximum(np.ones_like(g_nat),np.float64(Base[:,:,0]))
g_max=np.maximum(np.ones_like(g_max),np.float64(Base[:,:,1]))
z=g_nat

track_labels=Base[:,:,2]

numpoints=np.max(track_labels)

point=np.zeros((numpoints,2))

for i in range(0,Nx):
    for j in range(0,Ny):
        if (track_labels[i,j]>0):
            point[track_labels[i,j]-1]=np.array([i,j])
print (point)

# Trails (start and end point) For current Map, coordinates in metres, centre of image = (0,0)

# single possible path
# route=np.array([[24.,-9.75],[-24.,9.75]]),
# Out:
# []

# %%
# big field with tennis court parking lot and hospital, near rue cottrel
ptA = [-40.,-240.]      # tennis court near middle
ptB = [-250.,-200.]     # tennis court near skatepark
#ptC = [-350., 25.]     # parking lot entrance >>>>>>>>>>>>> removed because its very close to ptD, won't give interesting information, not worth computational work
ptD = [-350., 80.]      # parking lot bus stop
ptE = [-70., 230.]      # east road pedestrian entrance
ptF = [200., 200.]      # hospital bus stop
ptG = [250., 100.]      # hospital side path
ptH = [350., -100.]     # dirt car park
ptI = [210., -140.]     # west side entrance

#listofdestinations = [ptA,ptB,ptD,ptE,ptF,ptG,ptH,ptI,ptA,ptB,ptD,ptE,ptF,ptG,ptH,ptI] # list is repeated so that the combinations function below generates not only AB but BA
listofdestinations = [[0,25],[-10,-25],[10,-25],[0,25],[-10,-25],[10,-25],] #steiner points 200x200
#listofdestinations = [[0,10],[-5,-10],[5,-10],[0,10],[-5,-10],[5,-10]] #steiner points 200x200 (small scale)

##listofdestinations = [[150,25],[-165,45]] # fieldwithcrops
#listofdestinations = [[-165,45],[150,25],[0,-85],[-165,45],[150,25],[0,-85]] # fieldwithcrops
# listofdestinations = [[0,-85],[-165,45],[150,25],[0,-85],[-165,45],[150,25]]
#listofdestinations = [[0,-85],[150,25],[-165,45],[0,-85],[150,25],[-165,45]]

#listofdestinations = [[40,20],[-40,20],[40,-20],[-40,-20],[40,20],[-40,20],[40,-20],[-40,-20]] # criss cross thing

#listofdestinations = [[-375, -160], [-330, -50], [210, 110], [300, 20], [340, -80], [390, -150]] #madeleine
#listofdestinations = [[-25,-25],[25,25]]
route = []

#       should probably turn all of this into a function

# generate route combinations
for i in itertools.combinations(listofdestinations, 2):
    route.append(i)

# remove duplicate routes https://stackoverflow.com/questions/2213923/removing-duplicates-from-a-list-of-lists
routetemp = []
for i in route:
    if i not in routetemp:
        routetemp.append(i)
route = routetemp

# delete AA, BB, CC routes
zzzzz = -1
for row in route:
    zzzzz+=1
    if row[0] == row[1]:
        route.pop(zzzzz)

routearray = np.empty((len(route),2,2))

# convert list of lists to 3d array
for k in range(len(route)):
    for i in range(2):
        for j in range(2):
            routearray[k][i][j] = route[k][i][j]

route = routearray # convert routearray back to variable name understood by code
#route = [[[0,100],[-25,0]],[[0,100],[25,0]]]

#route = np.array([[[-30, 20],[0,40]],[[-30,-20],[0,-20]],[[0,20],[-30, 20]],[[0,-20],[-30,-20]]])

t_track=float(len(route)) # Track decay time - after 50 walkers ignore a trail, it decays by 1/e
#t_track = 12

# %%
#for i in listofdestinations
#    route[i,0:len(listofdestinations)] = listofdestinations[i]

# small field by apartment with 4 entrances 
#posA = [-5., -17.]
#posB = [-25., -17.]
#posC = [-25., 8.]
#posD = [40., 10.]

# acceptable routes = A/B to C, A/C to D and vice versa, 8 total routes
#route=np.array([[posA,posC],
#                 [posB,posC],
#                 [posC,posA],
#                 [posC,posD],
#                 [posA,posC],
#                 [posC,posD],
#                 [posD,posA],
#                 [posD,posC],
#                 ])

# %%
#Setup weight matrix, here trapezoid rule.
Weight[:,:]=1
Weight[1:-1,:]=2
Weight[:,1:-1]=2
Weight[1:-1,1:-1]=4
Weight*=0.25*((x[-1]-x[0])/(Nx-1))*((y[-1]-y[0])/(Ny-1))
#0.25*((x[-1]-x[0])/(N-1))*((y[-1]-y[0])/(N-1))
#np.exp(-np.sqrt((x[:,None]-x[N/2])**2+(y[None,:]-y[N/2])**2))*z[:,:]

# %%
# Setup distance matrix
for xi in range(1,Nx+1):
    for yi in range(1,Ny+1):
        
        expdist[xi-1,yi-1]=np.exp(-isigma*np.sqrt((x[Nx-xi]-xmin)**2+(y[Ny-yi]-ymin)**2))
        expdist[-xi,-yi]  = expdist[xi-1,yi-1]
        expdist[-xi,yi-1] = expdist[xi-1,yi-1]
        expdist[xi-1,-yi] = expdist[xi-1,yi-1]
        
# find index range > conv_thresh
subexpdist=expdist[(expdist>conv_thresh).any(1)]
subexpdist=subexpdist[:, np.any(subexpdist>conv_thresh, axis=0)]
#subexpdist=subexpdist[:,np.any(subexpdist>conv_thresh, axis=0)]
#expdist[subexpdist]=0.
subexpdist.shape
#expdist
#subexpdist
# Out:
# (139, 139)

# %%
def calc_tr_new():
    TrailPotential[:,:]=sg.convolve2d(z[:,:]*Weight[:,:],subexpdist[:,:],mode="same")  # 2D convolution

# %%
len(TrailPotential)
# Out:
# 200

# %%
def calc_tr_gauss():
    TrailPotential[:,:]=ndimage.gaussian_filter(z[:,:], 1, 0) #,TrailPotential,mode='nearest')

# %%
#Integrate z, trapezoid rule eq 20
#def calc_tr():
#    global xi,yi,tr,expdist,z,wght,Nx,Ny
#    for xi in range(0,Nx): 
#        for yi in range(0,Ny):
#            tr[xi,yi]=np.sum(expdist[Nx-1-xi:2*Nx-1-xi,Ny-1-yi:2*Ny-1-yi]*z[:,:]*wght[:,:])

# %%
timeit.timeit(calc_tr_new,number=1)
# Out:
# 1.1306511000002502

# %%
# Defines a Plot to show the smoothing of the supplied map to represent the respective potentials of the ground, the larger
# the potentials, the more attractive the ground is to the walker

cs = plt.contourf(X, Y, TrailPotential, levels=np.linspace(TrailPotential.min(),TrailPotential.max(),1000),cmap='PuBu_r')
cbar = plt.colorbar()

plt.show()
#plt.scatter(track[0:wlkr_range-1,0],track[0:wlkr_range-1,1])

# %%
#set up walker
def set_up_walker(route_id):
    global vel, pos, track, dest, start, route
    #start
    dispersion = 5 # length away from start point walkers are allowed to spawn, measured in m

    start = np.array(route[route_id, 0, :]) # commented for simplicity
    start[0] += np.random.randint(-dispersion, dispersion+1) # adds dispersion to x
    start[1] += np.random.randint(-dispersion, dispersion+1) # adds dispersion to y
    # start = np.array([24.,-9.75])  # temporary one route
    # dest = np.array([-24.,9.75])  # temporary one route
    # dest=(random.choice(ends))
    dest = np.array(route[route_id, 1, :]) # commented for simplicity
    dest[0] += np.random.randint(-dispersion, dispersion+1)
    dest[1] += np.random.randint(-dispersion, dispersion+1)
    vel = np.array([0., 0.])
    pos = np.array(start)
    #print (pos)
    track = np.zeros((wlkr_range, 2))
    #track[0,:]=pos[:]

# %%
#Calculate gradients eq 19
#Trail gradient
def setup_potentials():
    global grad,desdirx,desdiry,dest,trailpotweight
    grad=np.zeros((2,Nx,Ny))
    grad=trailpotweight*np.array(np.gradient(TrailPotential))
    #grad=0.002*np.array(np.gradient(TrailPotential)) ORIGINAL
    
    #print (dest)
    #Destination potential
    DestinationPotential=-np.sqrt((dest[0]-x[:,None])**2+(dest[1]-y[None,:])**2)
    #Combine gradients
    grad+=np.array(np.gradient(DestinationPotential)[:])
    #Normalise
    #grad[:,:,:]/=(np.sqrt(grad[0,:,:]**2+grad[1,:,:]**2))
    desdirx=ReBiSpline(x,y,grad[0,:,:],s=2) # gradeint plus magnitude, Spline approximation over a rectangular mesh
    desdiry=ReBiSpline(x,y,grad[1,:,:],s=2) 
    #plot()
    #print(grad)

# %%
# #Plot the direction
# scgrad=np.arctan2(grad[1],grad[0])
# levels = np.linspace(-np.pi, np.pi, 360)
# cs = plt.contourf(X, Y,scgrad, levels=levels,cmap='hsv')

# cbar = plt.colorbar()
# # ERROR # plt.scatter(track[0:wlkr_range-1,0],track[0:wlkr_range-1,1])
# #plt.scatter(start, dest)
# print(start)
# print(dest)
# plt.show()

# %%
# This function rounds a point, and checks if it is already in the list of rounded points
# If its already in the list it, it increases the count value for that point by 1
# If its not in the list, it adds it to the list with a count of 1

def stalledposregioncounter(newpos,stalledposrounded2):
    nearest = 5
    newposxrounded = round(newpos[0]/nearest)*nearest # round x
    newposyrounded = round(newpos[1]/nearest)*nearest # round y

    newposrounded = {"x":newposxrounded,"y":newposyrounded,"count":1}
    
    for i in stalledposrounded2:
        if i["x"] == newposrounded["x"] and i["y"] == newposrounded["y"]:
            i["count"]+=1
            return stalledposrounded2
    stalledposrounded2.append(newposrounded)
    return stalledposrounded2

# %%
def calc_path():
    global pos,vel,intens,track,dest,dvel,tau,stalledpos,stalledposrounded,trailpotweight,storedtrailpotweight
    
    i=0
    hist=10
    samp=10
    avpos=np.zeros((2,hist))
    internalclock = 0 # not measured in seconds, probably measured in 'dt's
    stallcounter = 0
    trailpotweight = 0.004 # weighting of trail potential over destination potential, started as 0.003, increasing this increases number of stalls
    storedtrailpotweight = trailpotweight

    # https://www.programiz.com/python-programming/datetime/current-time
    #now = datetime.now()
    #current_time = now.strftime("%H:%M:%S")
    #print("Calc path entered, time =", current_time)

    #Setup While loop to run until either the walker reaches the destination or the walker has passed 'wlkr_range' number of movement cycles to 
    #attempt to get there
    while (np.dot(pos-dest,pos-dest)>precision and i<wlkr_range):
    #set the postiion of the walker on its first then subsequent cycles
        
        #conditional logic saying to update the average position of the walker every 10 iterations
        #if (i%samp==0): avpos[:,(i%hist)//samp]=pos[:] #ORIGINAL
        if (i%samp==0): avpos[:,(i%(hist*samp))//samp]=pos[:]
            
        #print((i%hist)//samp)
        #print(avpos)
        
        gradmagnitude=max(0.0001,np.sqrt(desdirx(pos[0],pos[1])**2+desdiry(pos[0],pos[1])**2))
        xi=np.array(np.random.normal(0,1,2))
        # Equation 6 in Helbing, differential in position, eliminised velocity decay components
        # gradmagnitude makes sure it is normalised, desdir not normalised
        pos[0]+= dt *(dvel * desdirx(pos[0],pos[1])/gradmagnitude +np.sqrt(2.*eps/tau)*xi[0])  # x-position vector component 
        pos[1]+= dt *(dvel * desdiry(pos[0],pos[1])/gradmagnitude +np.sqrt(2.*eps/tau)*xi[1])  # y-position vector component
        
        internalclock+=1
        if internalclock == 250 and trailpotweight != storedtrailpotweight:
                trailpotweight = storedtrailpotweight
                #print(trailpotweight)
                setup_potentials() # recalculate potentials
        
#        posGrad = math.degree(math.atan(pos[0]/pos[1]) # future position
        curDir = math.atan(desdiry(pos[0],pos[1])/desdirx(pos[0],pos[1]))
#         print(posGrad)
        # print(curDir)
        # pos+=dt*vel
        
        #vel[0]+=-1/tau*vel[0] + (dvel/tau)*desdirx(pos[0],pos[1])/gradmagnitude+np.sqrt(2.*eps/tau)*xi[0]   # Eqiation 5 in Helbing, differential in velocity
        #vel[1]+=-1/tau*vel[1] + (dvel/tau)*desdiry(pos[0],pos[1])/gradmagnitude+np.sqrt(2.*eps/tau)*xi[1]
        
        #Set the current position of the walker into the trakc array for the current iteration
        track[i,:]=pos[:]

#        if math.isnan(pos[1])==1: 
#                print ("NaN error ",pos,vel, dest)
#                break

        intens[int((pos[0]-xmin)*(Nx-1)/(xmax-xmin)),int((pos[1]-ymin)*(Ny-1)/(ymax-ymin))]+=1.
        i+=1
        if (i%(hist*samp)==0):
            meanpos=np.mean(avpos,axis=1)
            if (np.dot(pos-meanpos,pos-meanpos)<precision): 
                #print ("Stalled progress ",pos,meanpos,vel, dest)
                #stalledpos.append(meanpos) # store positions where walkers are stalled
                #stalledposrounded = stalledposregioncounter(meanpos, stalledposrounded) # store ROUNDED positions of walker stalls and count occurence in rounded position
                trailpotweight = 0.002 # reduce tpotweight to favour destination more
                #print(trailpotweight)
                setup_potentials() # recalculate the trail potentials with lower weight
                internalclock = 0 # reset clock
                stallcounter+=1 # take notice of the fact that there was a stall
                #break
        if stallcounter == 3: # 3 represents the number of stalls before stopping the walker, this will happen with hard obstacles like buildings and water
                print ("Stalled progress ",pos,meanpos, dest)
                stalledpos.append(meanpos) # store positions where walkers are stalled
                stalledposrounded = stalledposregioncounter(meanpos, stalledposrounded) # store ROUNDED positions of walker stalls and count occurence in rounded position
                break
    if (i==wlkr_range): print ("Missed goal ",dest,pos)           
    return i    
#stopping condition

# %%
# Calculate Q_alpha (strength of markings) eq 15
def update_ground_old():
    global q_alpha,intens,z,g_max,t_track,g_nat
    q_alpha=intens*(1.-z/g_max)
    # Time evolution of ground potential
    #zdiff=(1./t_track)*(g_nat-z)+q_alpha
    z+=(1./t_track)*(g_nat-z)+q_alpha
    #cs = plt.contourf(X, Y, zdiff, cmap=cm.PuBu_r)
    #cbar = plt.colorbar()
    #plt.show
    #z[140:160,45:75]

# %%
# Calculate Q_alpha (strength of markings) eq 15
def update_ground():
    global q_alpha,intens,z,g_max,t_track,g_nat,Nx,Ny

    for zj in range(Nx):
        for zi in range(Ny):
            if z[zj][zi] > g_max[zj][zi]: z[zj][zi] = g_max[zj][zi]
            if z[zj][zi] < g_nat[zj][zi]: z[zj][zi] = g_nat[zj][zi]

    q_alpha=intens*(1.-z/g_max)
    # Time evolution of ground potential
    #zdiff=(1./t_track)*(g_nat-z)+q_alpha
    z+=(1./t_track)*(g_nat-z)+q_alpha

    for zj in range(Nx):
        for zi in range(Ny):
            if z[zj][zi] > g_max[zj][zi]: z[zj][zi] = g_max[zj][zi]
            if z[zj][zi] < g_nat[zj][zi]: z[zj][zi] = g_nat[zj][zi]

    #cs = plt.contourf(X, Y, zdiff, cmap=cm.PuBu_r)
    #cbar = plt.colorbar()
    #plt.show
    #z[140:160,45:75]

# %%
def plot_path():
    plt.contourf(X, Y, z, levels=np.linspace(0,z.max(),1000),cmap='PuBu_r')
    plt.colorbar()
    #plt.scatter(track[0:wlkr_range-1,0],track[0:wlkr_range-1,1],1,np.array([[0,1,0]]))
    plt.show(block=False)

# %%
def plot_path_line():
    plt.contourf(X, Y, z, levels=np.linspace(0,z.max(),1000),cmap='PuBu_r')
    plt.colorbar()
    plt.scatter(track[0:wlkr_range-1,0],track[0:wlkr_range-1,1],1,np.array([[0,1,0]]))
    plt.show(block=False)

# %%
def plot_path_intens():
    plt.contourf(X, Y, intens, levels=np.linspace(0,z.max(),1000),cmap='PuBu_r')
    plt.colorbar()
    #plt.scatter(track[0:wlkr_range-1,0],track[0:wlkr_range-1,1],1,np.array([[0,1,0]]))
    plt.show(block=False)

# %%
def plot_path2():
    global stalledpos
    markercolour = np.array([[1,0,0]])

    plt.contourf(X, Y, z, levels=np.linspace(z.min(),z.max(),1000),cmap='PuBu_r')
    
    stalledposarray = np.array(stalledpos)
    plt.scatter(stalledposarray[0:-1,0],stalledposarray[0:-1,1],1.,markercolour)
    plt.show(block=False)

# %%
def plot_path3():
    global stalledposrounded
    stalledposrounded3 = []

    markercolour = np.array([[1,0,0]])
    
    plt.contourf(X, Y, z, levels=np.linspace(z.min(),z.max(),1000),cmap='PuBu_r')
    
    for i in stalledposrounded:
        stalledposrounded3.append([i["x"],i["y"]])

    stalledposarray2 = np.array(stalledposrounded3)
    plt.scatter(stalledposarray2[0:-1,0],stalledposarray2[0:-1,1],1.,markercolour)
    plt.show(block=False)

# %%
multiprocessing.cpu_count()
# Out:
# 12

# %%
def detect_local_maxima(arr):
    # https://stackoverflow.com/questions/3684484/peak-detection-in-a-2d-array/3689710#3689710
    """
    Takes an array and detects the troughs using the local maximum filter.
    Returns a boolean mask of the troughs (i.e. 1 when
    the pixel's value is the neighborhood maximum, 0 otherwise)
    """
    # define an connected neighborhood
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.morphology.html#generate_binary_structure
    neighborhood = morphology.generate_binary_structure(len(arr.shape),2)
    # apply the local minimum filter; all locations of minimum value 
    # in their neighborhood are set to 1
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.filters.html#minimum_filter
    local_max = (filters.maximum_filter(arr, footprint=neighborhood)==arr)
    # local_min is a mask that contains the peaks we are 
    # looking for, but also the background.
    # In order to isolate the peaks we must remove the background from the mask.
    # 
    # we create the mask of the background
    background = (arr==0)
    # 
    # a little technicality: we must erode the background in order to 
    # successfully subtract it from local_min, otherwise a line will 
    # appear along the background border (artifact of the local minimum filter)
    # http://www.scipy.org/doc/api_docs/SciPy.ndimage.morphology.html#binary_erosion
    eroded_background = morphology.binary_erosion(
        background, structure=neighborhood, border_value=1)
    # 
    # we obtain the final mask, containing only peaks, 
    # by removing the background from the local_min mask
    detected_maxima = local_max ^ eroded_background
    return np.where(detected_maxima)

# %%
def plot_potentials():
    global dest
    TotPot = np.zeros((Nx,Ny))
    TotPot =- np.sqrt((dest[0]-x[:,None])**2+(dest[1]-y[None,:])**2)
    TotPot += 0.003*TrailPotential
    maxima=detect_local_maxima(TotPot)
    cs = plt.contourf(X, Y, TotPot, levels=np.linspace(TotPot.min(),TotPot.max(),1000),cmap='PuBu_r')
    cbar = plt.colorbar()
    print(maxima)
    plt.scatter(x[maxima[0]],y[maxima[1]])
    plt.scatter(track[0:wlkr_range-1,0],track[0:wlkr_range-1,1],1)
    plt.show
    # commit test

# %%
tau = 5

# %%
#rowval = np.empty((1,Ny))

# %%
# main loop
iterations = 25
walkersperiteration = 24
plotfrequency = 1 # number of plots you want (including final), make sure 'iterations' is divisible by this
plotevery = iterations/plotfrequency
stalledpos = []
walker_times = []
iteration_times = []
calc_tr_times = []
comparison_factor_array = []
stalledpos_stop_threshold = 1.1
endmainloop = 0
intensmaxvals = []
#convergence_threshold = ???

t11a = time.perf_counter()
for i in range(iterations):
        t11 = time.perf_counter()

        tpot_n_minus_1 = copy.deepcopy(TrailPotential)

        calc_tr_new() # original method

        #if __name__ == '__main__': # runs parallelised calc_tr --------------pixel method
        #    with Pool(processes = multiprocessing.cpu_count()) as pool:
        #        starmapargs = [] # container for starmap arguments
        #        for xi in range(0,Nx): 
        #            for yi in range(0,Ny):
        #                starmapargs.append((xi,yi,TrailPotential,expdist,z,Weight,Nx,Ny))
        #        results3 = pool.starmap(mpf3.calc_tr, starmapargs)
        #        for pixel in list(results3):
        #            xitemp = pixel[0]
        #            yitemp = pixel[1]
        #            valuetemp = pixel[2]
        #            TrailPotential[xitemp,yitemp] = valuetemp

        #if __name__ == '__main__': # runs parallelised calc_tr ------------row method
        #    with Pool(processes = multiprocessing.cpu_count()) as pool:
        #        starmapargs = [] # container for starmap arguments
        #        for xi in range(0,Nx):
        #                starmapargs.append((xi,TrailPotential,expdist,z,Weight,Nx,Ny))
        #        print('hello 1')
        #        results3 = pool.starmap(mpf3_2.calc_tr, starmapargs)
        #        print('hello 2')
        #        for row in list(results3):
        #            xitemp = row[0]
        #            valuetemp = row[1]
        #            TrailPotential[xitemp] = valuetemp

        #if __name__ == '__main__': # runs parallelised calc_tr
        #    with Pool(processes = multiprocessing.cpu_count()) as pool:
        #        starmapargs = [] # container for starmap arguments
        #        for core in range(1,multiprocessing.cpu_count()+1):
        #            starmapargs.append((core, TrailPotential, z, Weight, subexpdist)) # list of lists of args
        #        TrailPotential[:,:] = 0
        #        results = pool.starmap(mpf.calc_tr_new_mp, starmapargs)
        #        TrailPotential = np.concatenate(np.array(results[0:4]))
                #for ll in results:
                #    TrailPotential += np.array(ll)
                #Trailpotential = results
                #for core in results:

                #pool.close()
                #pool.join()

        tp_comparison_factor = np.mean(np.subtract(TrailPotential,tpot_n_minus_1))
        #if tp_comparison_factor > convergence_threshold: break
        print(tp_comparison_factor)
        comparison_factor_array.append(tp_comparison_factor)

        t22 = time.perf_counter()
        print(t22-t11,' = Time taken for calc_tr')
        calc_tr_times.append(t22-t11)

        intens[:]=0.
        stalledpos_tempcounter = 0

        if __name__ == '__main__': # runs parallelised set_up_walker
            with Pool(processes = 1) as pool2:
                starmapargs2 = []
                for j in range(walkersperiteration):
                    randomroute = np.random.randint(0,len(route))
                    starmapargs2.append((randomroute, route, intens, xmin, xmax, ymin, ymax, Nx, Ny, x, y, TrailPotential)) #random route
                    #starmapargs2.append((j, route, intens, xmin, xmax, ymin, ymax, Nx, Ny, x, y, TrailPotential))
                t11b = time.perf_counter()
                results2 = pool2.starmap(mpf10.set_up_walker_mp, starmapargs2)
                t22b = time.perf_counter()
                print(t22b-t11b,' = Time taken for iteration ', i,)
                iteration_times.append(t22b-t11b)
                for walker in list(results2):
                    print(i, walker[7], '|  Start: ', walker[0], 'Dest: ', walker[1], 'Pos: ', walker[2], 'Time of completion:', walker[8], 'Time taken: ', walker[9])
                    track = walker[3] # only keeping last walker's track data, for now

                    # experimental
                    if walker[7] == 'Reached Goal':
                        intens += walker[4] # summing intens from all (successful) walkers

                    #intens += walker[4] # summing intens from all walkers

                    grad = walker[6] # not sure if this should be last walker or sum of all NOTE: should probably be just the last one
                    walker_times.append(float(walker[9])) # collect times taken by walkers to go from A to B
                    # if there is a stall, append the coords to a list, count number of stalls in iteration
                    if len(walker[5]) != 0:
                        stalledpos.append(walker[5])
                        stalledpos_tempcounter +=1
                    # if number of stalls per iteration is too large, force stop main loop
                if stalledpos_tempcounter/walkersperiteration >= stalledpos_stop_threshold:
                    print('!!!!  Stopping early; number of stalls > threshold  !!!!')
                    endmainloop = 1

                finaliteration = i
                # collect relevant information from walkers
                
                intensmaxvals.append(np.max(intens)) # grab max value of intens, possibly for debugging/ sanity check

        t11c = time.perf_counter()
        update_ground()
        t22c = time.perf_counter()
        print(t22c-t11c,' = Time taken for update_ground ')
        #plot_path() 
        if (i+1) % plotevery == 0 and i != 0: plot_path()     
        #for j in range(0,walkersperiteration):
            #set_up_walker(np.random.randint(0,len(route))) # used if you want random routes
            #set_up_walker(j) # used if you want to run every route per potential calculation/ iteration
            #setup_potentials()
            #calc_path()
            #now = datetime.now() # referenced elsewhere
            #current_time = now.strftime("%H:%M:%S")
            #print(i, start," -> ", dest, pos,"      time = ", current_time)
        #update_ground()
        if endmainloop == 1: break
        #plot_path()
#print(str("Number of walkers = ")+str(numberofwalkers))
#print(str('Walker success rate = ')+str(successrate)+str(' %'))
#print('Average time taken for walker = '+str(np.mean(walker_times))+ ',    Min = '+str(min(walker_times))+',    Max = '+str(max(walker_times)))
#print('Average time taken for calc_tr = '+str(np.mean(calc_tr_times))+ ',    Min = '+str(min(calc_tr_times))+',    Max = '+str(max(calc_tr_times)))
t22a = time.perf_counter()
print(t22a-t11a, ' = Time taken for whole loop')
# Out:
# 0.0
# 1.1276866000002883  = Time taken for calc_tr
# 1.2025089999997363  = Time taken for iteration  0
# 0 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.30580643 24.11217832] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.29252595 24.11171334] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.79074391 -24.09038048] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.06228325 -24.8481393 ] Time of completion: 20:25:43 Time taken:  0.03
# 0 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.11069897 -24.81516632] Time of completion: 20:25:43 Time taken:  0.03
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.82015263 -24.06850797] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [ 0.09376129 24.01208219] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.79427601 -24.07642524] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.82236787 -24.02324992] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.8565852  -24.06907301] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.09515425 -24.81417056] Time of completion: 20:25:43 Time taken:  0.03
# 0 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.27510037 24.09035752] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.10283242 -24.79526357] Time of completion: 20:25:43 Time taken:  0.03
# 0 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [ 0.02913125 24.09057713] Time of completion: 20:25:43 Time taken:  0.04
# 0 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.04636274 -24.80363922] Time of completion: 20:25:43 Time taken:  0.03
# 0 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.06041544 -24.87681952] Time of completion: 20:25:43 Time taken:  0.03
# 0 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.06842808 -24.86254415] Time of completion: 20:25:43 Time taken:  0.03
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.83314949 -24.04400146] Time of completion: 20:25:44 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [ 0.06278287 24.05181473] Time of completion: 20:25:44 Time taken:  0.04
# 0 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.29220451 24.11723521] Time of completion: 20:25:44 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.78244217 -24.09822554] Time of completion: 20:25:44 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.03805492 -24.9102522 ] Time of completion: 20:25:44 Time taken:  0.03
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.74772368 -24.10160988] Time of completion: 20:25:44 Time taken:  0.04
# 0 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.82898962 -24.11931451] Time of completion: 20:25:44 Time taken:  0.04
# 0.04770039999993969  = Time taken for update_ground
# 132.82079546753033
# 1.1257817000000614  = Time taken for calc_tr
# 1.2639713000003212  = Time taken for iteration  1
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.10847463 24.05142037] Time of completion: 20:25:45 Time taken:  0.05
# 1 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.44912538 -24.27934978] Time of completion: 20:25:45 Time taken:  0.04
# 1 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.50931602 -24.21828129] Time of completion: 20:25:45 Time taken:  0.04
# 1 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.44371179 -24.2090488 ] Time of completion: 20:25:45 Time taken:  0.04
# 1 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.15054697 -24.53081939] Time of completion: 20:25:45 Time taken:  0.03
# 1 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.48902287 -24.18428545] Time of completion: 20:25:45 Time taken:  0.04
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.10435053 -24.56263809] Time of completion: 20:25:46 Time taken:  0.03
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.16787802 -24.57239546] Time of completion: 20:25:46 Time taken:  0.03
# 1 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.41859018 -24.19943292] Time of completion: 20:25:46 Time taken:  0.04
# 1 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.42236107 -24.24031227] Time of completion: 20:25:46 Time taken:  0.04
# 1 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.10619527 24.05264639] Time of completion: 20:25:46 Time taken:  0.05
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.10067102 24.07344404] Time of completion: 20:25:46 Time taken:  0.05
# 1 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.48087869 -24.18039695] Time of completion: 20:25:46 Time taken:  0.04
# 1 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.09411003 24.09734762] Time of completion: 20:25:46 Time taken:  0.05
# 1 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.18373732 -24.52285329] Time of completion: 20:25:46 Time taken:  0.03
# 1 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.52926561 -24.20533236] Time of completion: 20:25:46 Time taken:  0.04
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.10219544 -24.62064761] Time of completion: 20:25:46 Time taken:  0.03
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.13830681 -24.57734282] Time of completion: 20:25:46 Time taken:  0.03
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.09353699 -24.57799185] Time of completion: 20:25:46 Time taken:  0.03
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.1222556  24.02174991] Time of completion: 20:25:46 Time taken:  0.05
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.10714985 24.05448624] Time of completion: 20:25:46 Time taken:  0.05
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.10759634 24.05274518] Time of completion: 20:25:46 Time taken:  0.05
# 1 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.15176784 -24.54002148] Time of completion: 20:25:46 Time taken:  0.03
# 1 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.13388626 -24.60355592] Time of completion: 20:25:46 Time taken:  0.03
# 0.04812850000007529  = Time taken for update_ground
# 106.91716484677636
# 1.1300224999999955  = Time taken for calc_tr
# 1.5638455000002978  = Time taken for iteration  2
# 2 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.39094325 -24.28337168] Time of completion: 20:25:48 Time taken:  0.04
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07991016 24.07060762] Time of completion: 20:25:48 Time taken:  0.07
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.20786097 -24.41396736] Time of completion: 20:25:48 Time taken:  0.03
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.27908098 -24.42971755] Time of completion: 20:25:48 Time taken:  0.03
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.02967462 24.04166102] Time of completion: 20:25:48 Time taken:  0.07
# 2 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.40462131 -24.21903461] Time of completion: 20:25:48 Time taken:  0.04
# 2 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.24864429 -24.3788339 ] Time of completion: 20:25:48 Time taken:  0.05
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.08516521 24.08572366] Time of completion: 20:25:48 Time taken:  0.07
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.05740053 24.07974657] Time of completion: 20:25:48 Time taken:  0.07
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.19492241 -24.44876445] Time of completion: 20:25:48 Time taken:  0.03
# 2 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.28085438 -24.43414627] Time of completion: 20:25:48 Time taken:  0.04
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.0655656  24.07827933] Time of completion: 20:25:48 Time taken:  0.07
# 2 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.08197342 24.07592302] Time of completion: 20:25:48 Time taken:  0.07
# 2 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.41001659 -24.28821937] Time of completion: 20:25:48 Time taken:  0.04
# 2 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.09718942 24.04617748] Time of completion: 20:25:49 Time taken:  0.07
# 2 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.26776727 -24.42311003] Time of completion: 20:25:49 Time taken:  0.04
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.19145089 -24.44043386] Time of completion: 20:25:49 Time taken:  0.04
# 2 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.42446665 -24.2556745 ] Time of completion: 20:25:49 Time taken:  0.04
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.0670523  24.00760926] Time of completion: 20:25:49 Time taken:  0.07
# 2 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.27532537 -24.42631921] Time of completion: 20:25:49 Time taken:  0.04
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.27570463 -24.46791878] Time of completion: 20:25:49 Time taken:  0.03
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.08520394 24.04816119] Time of completion: 20:25:49 Time taken:  0.07
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.0515401  24.05356452] Time of completion: 20:25:49 Time taken:  0.07
# 2 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.18221698 -24.43173113] Time of completion: 20:25:49 Time taken:  0.03
# 0.04694160000008196  = Time taken for update_ground
# 75.72116386589305
# 1.1276394999999866  = Time taken for calc_tr
# 1.7195130999998582  = Time taken for iteration  3
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07090736 24.01163179] Time of completion: 20:25:51 Time taken:  0.08
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.22750012 -24.39651933] Time of completion: 20:25:51 Time taken:  0.08
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.30867213 -24.3499007 ] Time of completion: 20:25:51 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.3059525  -24.34489558] Time of completion: 20:25:51 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06475497 24.09123058] Time of completion: 20:25:51 Time taken:  0.08
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.28011931 -24.33903129] Time of completion: 20:25:51 Time taken:  0.03
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.31479025 -24.30991513] Time of completion: 20:25:51 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.30391265 -24.30457798] Time of completion: 20:25:51 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.34228045 -24.37693915] Time of completion: 20:25:51 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.31923125 -24.34644167] Time of completion: 20:25:51 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.21509571 -24.40277936] Time of completion: 20:25:51 Time taken:  0.08
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.30671845 -24.32232155] Time of completion: 20:25:51 Time taken:  0.03
# 3 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.0845709  24.03247481] Time of completion: 20:25:51 Time taken:  0.08
# 3 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.24688778 -24.43122943] Time of completion: 20:25:51 Time taken:  0.07
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06921025 24.08812822] Time of completion: 20:25:51 Time taken:  0.08
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.0868028  24.08116178] Time of completion: 20:25:51 Time taken:  0.08
# 3 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07259965 24.03870169] Time of completion: 20:25:52 Time taken:  0.08
# 3 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06935607 24.00937172] Time of completion: 20:25:52 Time taken:  0.07
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.33338556 -24.35222618] Time of completion: 20:25:52 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.24210103 -24.38958113] Time of completion: 20:25:52 Time taken:  0.08
# 3 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.32040698 -24.33366791] Time of completion: 20:25:52 Time taken:  0.03
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.30075556 -24.2913366 ] Time of completion: 20:25:52 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.29665155 -24.37668273] Time of completion: 20:25:52 Time taken:  0.04
# 3 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.24702485 -24.40722053] Time of completion: 20:25:52 Time taken:  0.08
# 0.047144200000275305  = Time taken for update_ground
# 68.63513801733299
# 1.1267754000000423  = Time taken for calc_tr
# 2.363388700000087  = Time taken for iteration  4
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.28028538 -24.41818361] Time of completion: 20:25:53 Time taken:  0.08
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.19927202 -24.50302722] Time of completion: 20:25:54 Time taken:  0.08
# 4 Stalled      |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.13173131 23.91118724] Time of completion: 20:25:54 Time taken:  0.10
# 4 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.2819901  -24.40745862] Time of completion: 20:25:54 Time taken:  0.07
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.17433759 -24.45797589] Time of completion: 20:25:54 Time taken:  0.09
# 4 Stalled      |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.03533361 23.89541815] Time of completion: 20:25:54 Time taken:  0.10
# 4 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.18837222 -24.47456626] Time of completion: 20:25:54 Time taken:  0.08
# 4 Stalled      |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.03773915 23.87824881] Time of completion: 20:25:54 Time taken:  0.10
# 4 Stalled      |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.15374644 23.85553036] Time of completion: 20:25:54 Time taken:  0.10
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.27754808 -24.41620496] Time of completion: 20:25:54 Time taken:  0.08
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.25173195 -24.34791599] Time of completion: 20:25:54 Time taken:  0.08
# 4 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.27174519 -24.41115497] Time of completion: 20:25:54 Time taken:  0.07
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.26778146 -24.38869787] Time of completion: 20:25:55 Time taken:  0.08
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.26467411 -24.39192245] Time of completion: 20:25:55 Time taken:  0.08
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.27336099 -24.4077967 ] Time of completion: 20:25:55 Time taken:  0.08
# 4 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.26049085 -24.5046061 ] Time of completion: 20:25:55 Time taken:  0.08
# 4 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.21112129 -24.48787619] Time of completion: 20:25:55 Time taken:  0.07
# 4 Stalled      |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.14788172 23.86710597] Time of completion: 20:25:55 Time taken:  0.10
# 4 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.18750825 -24.47696026] Time of completion: 20:25:55 Time taken:  0.08
# 4 Stalled      |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.11190095 23.87522244] Time of completion: 20:25:55 Time taken:  0.10
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.22868172 -24.50179184] Time of completion: 20:25:55 Time taken:  0.08
# 4 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.19994611 -24.48788928] Time of completion: 20:25:55 Time taken:  0.08
# 4 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.27090021 -24.3859496 ] Time of completion: 20:25:55 Time taken:  0.07
# 4 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.17203455 -24.45344645] Time of completion: 20:25:55 Time taken:  0.07
# 0.049102700000275945  = Time taken for update_ground
# 31.938231074492318
# 1.1241718999999648  = Time taken for calc_tr
# 2.1394295999998576  = Time taken for iteration  5
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.24655196 -24.35486542] Time of completion: 20:25:57 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.03652987 24.02850066] Time of completion: 20:25:57 Time taken:  0.08
# 5 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.05333581 24.01149788] Time of completion: 20:25:57 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.2926553  -24.40776044] Time of completion: 20:25:57 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06423507 24.07210453] Time of completion: 20:25:57 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.15212986 -24.57388474] Time of completion: 20:25:57 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.05880001 24.0258578 ] Time of completion: 20:25:58 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.28277768 -24.39981422] Time of completion: 20:25:58 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.27078725 -24.40147285] Time of completion: 20:25:58 Time taken:  0.07
# 5 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.03387851 24.03576378] Time of completion: 20:25:58 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.27073816 -24.40954289] Time of completion: 20:25:58 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.26037527 -24.39179057] Time of completion: 20:25:58 Time taken:  0.08
# 5 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.16553838 -24.59208522] Time of completion: 20:25:58 Time taken:  0.07
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.25943686 -24.33964152] Time of completion: 20:25:58 Time taken:  0.08
# 5 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.16197856 -24.59228979] Time of completion: 20:25:58 Time taken:  0.07
# 5 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06629059 24.05049725] Time of completion: 20:25:58 Time taken:  0.08
# 5 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.1555084  -24.59912031] Time of completion: 20:25:58 Time taken:  0.07
# 5 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.05124564 24.03170885] Time of completion: 20:25:58 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.29395349 -24.37321283] Time of completion: 20:25:58 Time taken:  0.07
# 5 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.16149383 -24.59538232] Time of completion: 20:25:59 Time taken:  0.07
# 5 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.08963214 24.05476382] Time of completion: 20:25:59 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.16818963 -24.56802389] Time of completion: 20:25:59 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.15557471 -24.57650679] Time of completion: 20:25:59 Time taken:  0.08
# 5 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.05520263 24.00349679] Time of completion: 20:25:59 Time taken:  0.08
# 0.045435400000314985  = Time taken for update_ground
# 34.67412023383089
# 1.1337967999998  = Time taken for calc_tr
# 2.0989129999998113  = Time taken for iteration  6
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07614552 24.06221262] Time of completion: 20:26:00 Time taken:  0.07
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.14044201 -24.50542781] Time of completion: 20:26:00 Time taken:  0.08
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.17666454 -24.79648558] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.04422291 24.05074116] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.13161375 -24.56874108] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07218121 24.01134591] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.15897458 -24.63061537] Time of completion: 20:26:01 Time taken:  0.08
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.17280018 -24.64313203] Time of completion: 20:26:01 Time taken:  0.08
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07278147 24.0083177 ] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.13614887 -24.56112131] Time of completion: 20:26:01 Time taken:  0.08
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.14055254 -24.52251732] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.22832299 -24.40757548] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.05719009 24.05517073] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.25241349 -24.48798419] Time of completion: 20:26:01 Time taken:  0.08
# 6 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.21065518 -24.39039196] Time of completion: 20:26:01 Time taken:  0.07
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.03728787 24.11033337] Time of completion: 20:26:02 Time taken:  0.07
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.16268616 -24.53649637] Time of completion: 20:26:02 Time taken:  0.07
# 6 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.2334958  -24.43889438] Time of completion: 20:26:02 Time taken:  0.08
# 6 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.1739754  -24.87497124] Time of completion: 20:26:02 Time taken:  0.08
# 6 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.23759247 -24.43889308] Time of completion: 20:26:02 Time taken:  0.08
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.12265001 -24.57276905] Time of completion: 20:26:02 Time taken:  0.08
# 6 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.24848764 -24.39109775] Time of completion: 20:26:02 Time taken:  0.07
# 6 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.12771591 -24.55992327] Time of completion: 20:26:02 Time taken:  0.07
# 6 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07037398 24.0622155 ] Time of completion: 20:26:02 Time taken:  0.07
# 0.04622799999970084  = Time taken for update_ground
# 19.812277024236757
# 1.1252370000001974  = Time taken for calc_tr
# 2.4877166999999645  = Time taken for iteration  7
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.13389083 -24.5497721 ] Time of completion: 20:26:04 Time taken:  0.12
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.24587897 -24.36920853] Time of completion: 20:26:04 Time taken:  0.08
# 7 Stalled      |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.06126361 -24.33446137] Time of completion: 20:26:04 Time taken:  0.11
# 7 Stalled      |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.03471359 23.85783852] Time of completion: 20:26:04 Time taken:  0.10
# 7 Stalled      |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.11133549 -24.41748401] Time of completion: 20:26:04 Time taken:  0.11
# 7 Stalled      |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.08618556 -24.38519216] Time of completion: 20:26:04 Time taken:  0.10
# 7 Stalled      |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  8.99946659 -24.36235696] Time of completion: 20:26:04 Time taken:  0.11
# 7 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.26993865 -24.38952593] Time of completion: 20:26:04 Time taken:  0.07
# 7 Stalled      |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.03730051 -24.34112537] Time of completion: 20:26:05 Time taken:  0.11
# 7 Stalled      |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.07344682 -24.35855501] Time of completion: 20:26:05 Time taken:  0.11
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.14042191 -24.76982333] Time of completion: 20:26:05 Time taken:  0.08
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.25914917 -24.40896495] Time of completion: 20:26:05 Time taken:  0.08
# 7 Stalled      |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.08071542 -24.47778172] Time of completion: 20:26:05 Time taken:  0.11
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.27249654 -24.46396542] Time of completion: 20:26:05 Time taken:  0.08
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.24359677 -24.40541447] Time of completion: 20:26:05 Time taken:  0.08
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.26289359 -24.3999656 ] Time of completion: 20:26:05 Time taken:  0.08
# 7 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.23893607 -24.37140636] Time of completion: 20:26:05 Time taken:  0.07
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.25983268 -24.41500077] Time of completion: 20:26:05 Time taken:  0.08
# 7 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.13267139 -24.52986526] Time of completion: 20:26:05 Time taken:  0.07
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.22250877 -24.38418836] Time of completion: 20:26:06 Time taken:  0.08
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.26458648 -24.45751997] Time of completion: 20:26:06 Time taken:  0.08
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.29013306 -24.46053448] Time of completion: 20:26:06 Time taken:  0.08
# 7 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.25643938 -24.38503689] Time of completion: 20:26:06 Time taken:  0.07
# 7 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.27403012 -24.44779077] Time of completion: 20:26:06 Time taken:  0.08
# 0.04620160000013129  = Time taken for update_ground
# 13.768276043312365
# 1.1284270999999535  = Time taken for calc_tr
# 2.1500918000001548  = Time taken for iteration  8
# 8 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.08420209 24.02325289] Time of completion: 20:26:07 Time taken:  0.07
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.25253293 -24.41546796] Time of completion: 20:26:07 Time taken:  0.07
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.25568431 -24.38714183] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.25127716 -24.37639481] Time of completion: 20:26:08 Time taken:  0.08
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.27050603 -24.41957005] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06343977 24.08734732] Time of completion: 20:26:08 Time taken:  0.08
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.2253747  -24.39383125] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.24208813 -24.41758364] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.28543012 -24.48506519] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.28067273 -24.44753264] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.25566535 -24.39853211] Time of completion: 20:26:08 Time taken:  0.08
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.08106606 24.00524193] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.08310608 24.06916668] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07811236 24.07618837] Time of completion: 20:26:08 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.26774813 -24.39572388] Time of completion: 20:26:08 Time taken:  0.08
# 8 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.09544016 24.04600893] Time of completion: 20:26:09 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.25566923 -24.4521505 ] Time of completion: 20:26:09 Time taken:  0.08
# 8 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.22159468 -24.39749652] Time of completion: 20:26:09 Time taken:  0.08
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.28055451 -24.60087583] Time of completion: 20:26:09 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07719563 24.08876582] Time of completion: 20:26:09 Time taken:  0.07
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.21813298 -24.39968392] Time of completion: 20:26:09 Time taken:  0.07
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07997928 24.0787979 ] Time of completion: 20:26:09 Time taken:  0.07
# 8 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.24732538 -24.45072032] Time of completion: 20:26:09 Time taken:  0.07
# 8 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.22231537 -24.40899672] Time of completion: 20:26:09 Time taken:  0.08
# 0.05052780000005441  = Time taken for update_ground
# 16.9675485905556
# 1.1289141000002019  = Time taken for calc_tr
# 2.3312160999998923  = Time taken for iteration  9
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.21611414 -24.38021674] Time of completion: 20:26:11 Time taken:  0.07
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.22655905 -24.37822145] Time of completion: 20:26:11 Time taken:  0.07
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.08781984 24.01864755] Time of completion: 20:26:11 Time taken:  0.08
# 9 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.21117151 -24.46980453] Time of completion: 20:26:11 Time taken:  0.07
# 9 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07442241 24.04556948] Time of completion: 20:26:11 Time taken:  0.08
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.27746549 -24.47022462] Time of completion: 20:26:11 Time taken:  0.07
# 9 Stalled      |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.09486535 -24.32222916] Time of completion: 20:26:11 Time taken:  0.12
# 9 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.21736616 -24.7005097 ] Time of completion: 20:26:11 Time taken:  0.08
# 9 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.20464918 -24.43048008] Time of completion: 20:26:11 Time taken:  0.07
# 9 Stalled      |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.06893236 -24.26629398] Time of completion: 20:26:11 Time taken:  0.11
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06470215 24.07503282] Time of completion: 20:26:12 Time taken:  0.08
# 9 Reached Goal |  Start:  [ 0. 25.] Dest:  [-10. -25.] Pos:  [ -9.25151305 -24.43795365] Time of completion: 20:26:12 Time taken:  0.08
# 9 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.21062786 -24.39441302] Time of completion: 20:26:12 Time taken:  0.12
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.07821365 24.01824289] Time of completion: 20:26:12 Time taken:  0.08
# 9 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.21426079 -24.46545146] Time of completion: 20:26:12 Time taken:  0.08
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.22823408 -24.4031002 ] Time of completion: 20:26:12 Time taken:  0.07
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06848036 24.07214567] Time of completion: 20:26:12 Time taken:  0.08
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.28280907 -24.45190468] Time of completion: 20:26:12 Time taken:  0.07
# 9 Reached Goal |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.20954516 -24.48965573] Time of completion: 20:26:12 Time taken:  0.08
# 9 Stalled      |  Start:  [ 0. 25.] Dest:  [ 10. -25.] Pos:  [  9.13798695 -24.32938245] Time of completion: 20:26:12 Time taken:  0.12
# 9 Reached Goal |  Start:  [-10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06026316 24.09710717] Time of completion: 20:26:12 Time taken:  0.08
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [ 0. 25.] Pos:  [-0.06588558 24.06908637] Time of completion: 20:26:13 Time taken:  0.08
# 9 Reached Goal |  Start:  [-10. -25.] Dest:  [ 10. -25.] Pos:  [  9.18129897 -24.43527713] Time of completion: 20:26:13 Time taken:  0.11
# 9 Reached Goal |  Start:  [ 10. -25.] Dest:  [-10. -25.] Pos:  [ -9.2569643 -24.4218928] Time of completion: 20:26:13 Time taken:  0.07
# 0.04725289999987581  = Time taken for update_ground
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\William\Desktop\3rd year project\main_lineartest2.ipynb Cell 34' in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=17'>18</a> t11 = time.perf_counter()
#      <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=19'>20</a> tpot_n_minus_1 = copy.deepcopy(TrailPotential)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=21'>22</a> calc_tr_new() # original method
#      <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=23'>24</a> #if __name__ == '__main__': # runs parallelised calc_tr --------------pixel method
#      <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=24'>25</a> #    with Pool(processes = multiprocessing.cpu_count()) as pool:
#      <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=25'>26</a> #        starmapargs = [] # container for starmap arguments
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=62'>63</a>         #pool.close()
#      <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=63'>64</a>         #pool.join()
#      <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000033?line=65'>66</a> tp_comparison_factor = np.mean(np.subtract(TrailPotential,tpot_n_minus_1))
#
# c:\Users\William\Desktop\3rd year project\main_lineartest2.ipynb Cell 11' in calc_tr_new()
#       <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000010?line=0'>1</a> def calc_tr_new():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/William/Desktop/3rd%20year%20project/main_lineartest2.ipynb#ch0000010?line=1'>2</a>     TrailPotential[:,:]=sg.convolve2d(z[:,:]*Weight[:,:],subexpdist[:,:],mode="same")
#
# KeyboardInterrupt:

# %%
# shortcut (ignore this comment, its for CTRL+F purposes)
plot_path()

cs = plt.contourf(X, Y, TrailPotential, levels=np.linspace(TrailPotential.min(),TrailPotential.max(),1000),cmap='PuBu_r')
cbar = plt.colorbar()

plt.show()

z_copy = copy.deepcopy(z)

#for i in range (len(z[0])):
#    for j in range (len(z)):
#        if z[i][j] >= 199:
#            z_copy[i][j] = 180
#        elif 150 <= z[i][j] < 199:
#            z_copy[i][j] = 90
#        else:
#            z_copy[i][j] = 0

def plot_path_threshold():
    plt.contourf(X, Y, z, levels=np.linspace(-20,180,100),cmap='terrain')
    plt.colorbar()
    #plt.scatter(track[0:wlkr_range-1,0],track[0:wlkr_range-1,1],1)
    plt.show(block=False)

plot_path_threshold()

numberofwalkers = (finaliteration+1)*walkersperiteration
successrate = 100-(100*len(stalledpos))/numberofwalkers

print('isigma = ',isigma)
print('trailpotweight = ','0.004')
print('trailpotweight (after stall) = ','0.002')
print('t_track =',t_track)

#print(str("Number of walkers = ")+str(finaliteration*walkersperiteration+stalledpos_stop_threshold*walkersperiteration))
print("Number of walkers = ",walkersperiteration*(finaliteration+1))
print("Number of iterations = ",finaliteration+1)
print('Walkers per iteration = ',walkersperiteration)



print(str('Walker success rate = ')+str(successrate)+str(' %'))
print('Average time taken per walker = '+str(np.mean(walker_times))+ ',    Min = '+str(min(walker_times))+',    Max = '+str(max(walker_times)))
print('Average time taken per iteration = '+str(np.mean(iteration_times))+ ',    Min = '+str(min(iteration_times))+',    Max = '+str(max(iteration_times)))
print('Average time taken for calc_tr = '+str(np.mean(calc_tr_times))+ ',    Min = '+str(min(calc_tr_times))+',    Max = '+str(max(calc_tr_times)))
print('Time taken for whole loop = ',t22a-t11a)

# %%
plt.boxplot([walker_times], labels=['Walker times'])

# %%
plt.boxplot([iteration_times], labels=["Iteration times"])

# %%
plt.boxplot([calc_tr_times], labels=["'Calc_tr' times"])

# %%
plt.plot(comparison_factor_array)
print(comparison_factor_array[-1])

# %%
plt.plot(iteration_times)

# %%
plt.plot(calc_tr_times)

# %%
plt.plot(walker_times)

# %%
for i in range(0,Nx):
    for j in range(0,Ny):
        if (np.isnan(z[i,j])):
            print (i,j,g_max[i,j],Base[i,j,0])

# %%
for i in range(0,Nx):
    for j in range(0,Ny):
        if (np.isnan(z[i,j])):
            print (i,j,g_max[i,j],Base[i,j,0])

# %%
plot_potentials()

# %%
TrailPotential = sg.convolve2d(z*Weight,subexpdist[:,:],mode="same")
#print(TrailPotential)

# %%
#Plot the direction
scgrad=np.arctan2(grad[1],grad[0])
levels = np.linspace(-np.pi, np.pi, 360)
cs = plt.contourf(X, Y,scgrad, levels=levels,cmap='hsv')

cbar = plt.colorbar()
plt.scatter(track[0:wlkr_range-1,0],track[0:wlkr_range-1,1])
#plt.scatter(start, dest)
print(start)
print(dest)
plt.show()

# %%
plot_path2()

# %%
#Integrate z, trapezoid rule eq 20
# def calc_tr():
#    global xi,yi,TrailPotential,expdist,z,Weight,Nx,Ny
#    for xi in range(0,Nx): 
#        for yi in range(0,Ny):
#            TrailPotential[xi,yi]=np.sum(expdist[Nx-1-xi:2*Nx-1-xi,Ny-1-yi:2*Ny-1-yi]*z[:,:]*Weight[:,:])
